# %% [markdown]
# # Giới thiệu về ggplot2
# ggplot2 là một package đồ hoạ mạnh
#
# ggplot2 có nghĩa là Grammar of Graphics
#
# Nguyên lý ngữ pháp biểu đồ trong ggplot2
#
# Plot = data + Aesthetics + Geometry
#
# data: dữ liệu ở dạng data frame
#
# Aesthetics: sử dụng để quy định các biến cho trục Ox và Oy. Ngoài ra có thể sử dụng để điều chỉnh màu,
# kích cỡ, hình dạng,… của biểu đồ.
#
# Geometry: Thiết lập kiểu biểu đồ mà cần thể hiện (như histogram, box plot, line plot, density plot, dot plot,..
#
# Ngoài ra có thể thêm các lớp không bắt buộc như:
#
# Tính toán thống kê (statistical transformation): Sử dụng các tính toán trong biểu đồ. VD: Thêm các biểu đồ xu hướng dạng trơ (geom_smooth) , số lượng bin trong histogram… Lớp này có thể nằm lồng trong các lớp khác)
#
# Tỷ lệ (scale): Xác định tỷ lệ trong biểu đồ
#
# Trục tọa độ (Coordinate): Xác định hệ trục tọa độ vẽ biểu đồ. VD: Hệ tọa độ 3 trục trong không gian (hệ tọa đồ Descartes), hệ tọa độ cực
#
# Hệ thống Facet (tạm dịch: cách thức sắp xếp số liệu trên cùng 1 biểu đồ): Xác định cách thức sắp xếp vị trí của nhiều biểu đồ trên cùng một màn hình.
#
# Các yếu tố khác: Tên biểu đồ, tên trục, chú giải,
#
# **Hai hàm chính được sử dụng để tạo biểu đồ trong ggplot2 là:
#
# qplot(): Hàm tạo biểu đồ nhanh, dễ sử dụng dành cho các biểu đồ đơn giản
#
# qqplot(): Hàm linh hoạt và mạnh mẽ hơn qplot() để xây dựng biểu đồ bằng các lớp chồng lên nhau

# %%
# Cài đặt và load ggplot2
install.packages('ggplot2')   # Installation 
library(ggplot2)              # Loading
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# package 'ggplot2' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Minh Duy\AppData\Local\Temp\Rtmpageqbt\downloaded_packages
# Warning message:
# "package 'ggplot2' was built under R version 3.6.3"

# %%
library(ggplot2) 
#x=1:100: trục x tạo ngẫu nhiên từ 1 đến 100
#y=rnorm (200,0,1) tạo dãy ngẫu nhiên gồm 200 số với giá trị trung bình là 0 và độ lệch chuẩn là 1
df <- data.frame(x=1:100,y = rnorm(200,0,1))
#Nếu chỉ dùng ggplot sẽ không có kết quả hiện ra
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows

# %%
#Qui định kiểu đồ thị là point
ggplot(df) + geom_point(aes(x,y))
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %% [markdown]
# # Thành phần chính trên đã có thể tạo nên một graph cơ bản. Tuy nhiên để tùy chỉnh chuyên sâu hơn chúng ta cần có thêm các phần khác:
#
# theme(): qui định theme cho đồ thị trong đó có nhiều kiểu theme khác nhau như:
#
# theme() hoặc theme_gray() là theme mặc định có phông nhạt và gridlines trắng.
#
# theme_bw() là kiểu đồ thị phông trắng có gridlines trắng.
#
# theme_classic() phông trắng không có gridlines.
#
# theme_minimal() phông tối giản không có trục tọa độ,.
#
# theme_dark() phông nền tối có gridlines.
#
# theme_void() phông nền empty.
#
# them_light() phông nền trắng với gridlines đen.
#
# theme_lightdraw() phông nền trắng với gridlines và axis xám. Trong theme lại bao gồm 2 arguments đó là: base_size qui định font size của tiêu đề, base_family qui định kiểu chữ của các tiêu đề.

# %%
library(ggplot2)
df <- data.frame(x=1:100,y = rnorm(200,0,1))
ggplot(df) + geom_point(aes(x,y)) + theme_minimal()
# Out:
# plot without title

# %%
library(ggplot2)
df <- data.frame(x=1:100,y = rnorm(200,0,1))
# labs(): qui định các thành phần về title, subtitle, tên trục x, y
ggplot(df) + geom_point(aes(x,y)) + theme_minimal() + 
labs(title = "First plot",subtitle = "Point Graph", x = "x axis", y = "y axis")
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %% [markdown]
# # 1. Phân tán màu sắc theo scale
# scale_*_gradient tạo thành 2 màu gradient (low-high), scale_*_gradient2 tạo thành màu sắc phân tán thành (lowmid-high), scale_*_gradientn tạo thành n-colour gradient.
#
# Có thể tạo hệ màu sắc theo hàm terrain. Khi đó các mã hex của màu sắc sẽ được tạo ra tự động.
#
# Lưu ý mã hex của màu sắc luôn bắt đầu bởi dấu # và gồm 6-8 kí tự. Các kí tự là chữ số phải nằm trong khoảng từ 0-9 hoặc
# chữ cái từ A-F.

# %%
#Tạo 5 màu tự động
terrain.colors(5,alpha = 0.2)
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# [1] "#00A60033" "#E6E60033" "#EAB64E33" "#EEB99F33" "#F2F2F233"

# %%
# Chọn màu sắc theo scale của cty
ggplot(mpg) +
geom_point(aes(hwy,displ, colour = cty)) +
scale_colour_gradientn(colours = terrain.colors(10))
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %% [markdown]
# # 2. Scale theo alpha
# Đây là cách scale cũng tương tự như gradient nhưng sử dụng chỉ số độ trong suốt Alpha-transparency để biểu diễn các điểm theo mức độ quan trọng.
#
# Các hàm có dạng:
#
#  scale_alpha(..., range = c(0.1, 1)): scale cho các biến liên tục
#
#  scale_alpha_continuous(..., range = c(0.1, 1)): scale cho các biến liên tục
#
#  scale_alpha_discrete(..., range = c(0.1, 1)): scale cho các biến phân loại
#
#  Trong đó các arguments có ý nghĩa như sau:
#
#  …: Các argument được pass vào để control name, limits, breaks, labels,…
#
#  range: Output của alpha và phải nằm trong khoảng 0 và 1.

# %%
#Scale theo biến liên tục.
ggplot(mpg, aes(displ,hwy))+
geom_point(aes(alpha = year)) +
scale_alpha(range = c(0.2,1))
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
#Scale theo biến phân loại
ggplot(mpg, aes(displ,hwy))+
geom_point(aes(alpha = class)) +
scale_alpha_discrete(range=c(0.2,1))
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windowsWarning message:
# "Using alpha for a discrete variable is not advised."
# plot without title

# %% [markdown]
# # 3. Scale theo colour
#
#  Scale theo các màu sắc được cung cấp theo chuỗi sequential (tuần tự), chuỗi diverging (phân tán) và các chuỗi qualitative (chất lượng) sẵn có từ ColorBrewer. Có thể xem thêm trên website Colorbrewer.org  scale_colour_brewer(..., type = "seq", palette = 1, direction = 1)  scale_fill_brewer(..., type = "seq", palette = 1, direction = 1)  scale_colour_distiller(..., type = "seq", palette = 1, direction = -1, values = NULL, space = "Lab", na.value = "grey50", guide = "colourbar")
#
#  scale_fill_distiller(..., type = "seq", palette = 1, direction = -1, values = NULL, space = "Lab", na.value = "grey50", guide = "colourbar")
#
# Đối với các biểu đồ dạng rectangle ta sẽ như barchart hay heatmap ta phải dùng scale_fill, còn các biểu đồ của point ta sẽ dùng scale_colour.
#
# Trong đó :
#  …: là các argument khác để định nghĩa names, limits, breaks, labels.
#
#  type: là 3 kiểu lựa chọn sequential, diverging, qualitative.
#
#  palette: tên của bảng màu, có thể là string hoặc index.
#
#  direction: thứ tự các màu trong bảng màu, 1 là thứ tự tăng dần, -1 là ngược chiều.
#
#  values: Đánh số thứ tự trong vector gradient, hầu hết để NULL
#
#  space: Không gian màu sắc để từ đó tính toán gradient, nên chọn là “Lab” vì những space khác đã depreciated.
#
#  na.value: màu sử dụng cho missing value.
#
#  guide: Kiểu đánh màu gồm “colourbar” cho các màu liên tục, “legend” cho các màu phân loại.
#
# Lưu ý:
#
#  Các palettes chính của 3 loại seqential, diverging và qualitative gồm:
#
#  Diverging BrBG, PiYG, PRGn, PuOr, RdBu, RdGy, RdYlBu, RdYlGn, Spectral
#
#  Qualitative Accent, Dark2, Paired, Pastel1, Pastel2, Set1, Set2, Set3
#
#  Sequential Blues, BuGn, BuPu, GnBu, Greens, Greys, Oranges, OrRd, PuBu, PuBuGn, PuRd, Purples, RdPu, Reds, YlGn, YlGnBu, YlOrBr, YlOrRd
#
#  các scale_colour_distiller sẽ mở rộng các brewer thành các các scales liên tục bằng phương pháp interpolate 6 màu sắc khác nhau trong mỗi palette.

# %%
#màu sắc mặc định theo class
(p <- ggplot(mpg, aes(displ, hwy)) +
geom_point(aes(colour = class)))
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
#scale theo color brewer
p + scale_colour_brewer("Class of ܹn cars")
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
#scale sử dụng palettes Accent của Qualitative
p + scale_color_brewer(palette = "Accent")
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
#scale sử dụng palettes Set1 của sequential 
p + scale_color_brewer(palette = "Set1")
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
#Scale trong biểu đồ histogram
(h <- ggplot(diamonds, aes(x=price, fill=cut))+ geom_histogram(position = "dodge", binwidth = 1500))
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
#Lưu ý đối với biểu đồ barchart ta phải dùng scale_fill thay cho scale_colour
h + scale_fill_brewer()
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
#Đảo ngược vị trí màu sắc
h + scale_fill_brewer(direction = -1)
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
#Sử dụng scale_fill trong heatmap
(v <- ggplot(faithfuld) + geom_tile(aes(waiting, eruptions, fill = density)))
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
#Scale theo màu sắc bằng nhóm màu phân tán Spectral của palatte Diverging.
v + scale_fill_distiller(palette = "Spectral")
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
ggplot(mpg, aes(displ, hwy)) + geom_point(aes(colour = class))
# Out:
# plot without title

# %% [markdown]
# # 4 Scale theo thời gian
#
#  scale_*_date: scale time cho các kiểu thời gian thuộc class Date
#
#  scale_*_datetime: dành cho các class POSIXct
#
#  scale_*_time: dành có các kiểu thời gian thuộc class hms
#
# Cú pháp chung:
#
#  scale_y_datetime(name = waiver(), breaks = waiver(), date_breaks = waiver(), labels = waiver(), date_labels = waiver(), minor_breaks = waiver(), date_minor_breaks = waiver(), timezone = NULL,limits = NULL, expand = waiver(), position = "left")
#
# Trong đó:
#
#  break: Khoảng break là bao nhiêu, có thể nhận các giá trị NULL (không break), waiver() theo mặc định package tính toán, một
# numeric vector của position, một hàm số trả về các khoảng breaks.
#
#  date_break: Xác định khoảng thời gian giữa các bước liên tiếp là bao nhiêu như “2 weeks”, “10 years”,…
#
#  labels: Là một trong những giá trị NULL (không có labels), waiver() là default label của package tính ra, một character vector gán nhãn cho labels(phải có độ dài = breaks), hoặc một function trả về labels.
#
#  date_labels: Là kí tự định dạng format thời gian cho labels. VD “%Y %b”, code này phải tuân theo kiểu strftime. Nếu labels được định dạng cùng với date_labels thì date_labels thắng.  limits: là vector cung cấp độ dài của scale gồm 2 điểm đầu và cuối. Chẳng hạn như c(as.Date(“2018-04-21”)-7,NA), c(as.Date(“2018- 04-21”),as.Date(“2019-04-21”))

# %%
last_month <- Sys.Date() - 0:29
df <- data.frame( date = last_month, price = runif(30) )
#Vẽ biểu đồ với định dạng time là yyyy-mm-dd
#Gõ strftime để biết định dạng time khi convert date.
ggplot(df,aes(date,price))+ geom_line() + scale_x_date(date_labels = "%Y-%m-%d")
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
strftime
# Out:
# function (x, format = "", tz = "", usetz = FALSE, ...)
# format(as.POSIXlt(x, tz = tz), format = format, usetz = usetz,
#     ...)
# <bytecode: 0x000000005f1f7328>
# <environment: namespace:base>

# %%
#Khai báo date break là 1 tuần 
ggplot(df,aes(date,price))+ geom_line() + scale_x_date(date_breaks = "1 week",date_labels = "%W")
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
#Chuyển sang dat ebreak = 1 ngày
ggplot(df,aes(date,price))+ geom_line() + scale_x_date(date_breaks = "1 day",date_labels = "%d")
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
#Set date limit
ggplot(df,aes(date,price))+ geom_line() + scale_x_date(date_breaks = "1 day",date_labels = "%Y-%b-%d",limits = c(Sys.Date()-7,NA))
# Out:
# Warning message:
# "Removed 22 row(s) containing missing values (geom_path)."
# plot without title

# %% [markdown]
# # Ggplot2-Chia đồ thị thành nhiều facet
#
# 2 hàm facet_wrap() và facet_grid() sử dụng để phân chia 1 đồ thị thành nhiều facet khác nhau. Trong đó:
#
#  facet_wrap(): phân chia 1 mảnh đồ thị thành nhiều mảnh facet khác nhau. Nó được sử dụng phổ biến hơn so với
#
#  facet_grid() vì các hiểu thị đều đưa ra kết quả hình chữ nhật. Cú pháp:
#
#  facet_wrap(facets, nrow = NULL, ncol = NULL, scales = "fixed", shrink = TRUE, labeller = "label_value", as.table = TRUE, drop = TRUE, dir = "h", strip.position = "top")
#
#  Trong đó một số argument chính:
#
#  facets: là công thức hoặc vector. Khi là công thức thì chỉ có 1 side chẳng hạn ~a+b, khi là vector sẽ có dạng c(“a”,“b”) qui định chiều sử dụng để phân loại dữ liệu thành các nhóm và mỗi nhóm sẽ được vẽ trên 1 facet. * nrow, ncol: qui định số dòng, số cột để sắp xếp các facets.
#
#  labeller: xác định label được hiển thị cho mỗi facet. Thông thường sẽ dùng “label_both”
#
#  scales: scales ở các trục x,y được fixed, free hoặc free 1 trong 2 trục với free_x hoặc free_y
#
#  strip.position: thay đổi vị trí các label. Có các option (“top”,“bottom”,“left”,“right”)
#
#  dir: thay đổi chiều biểu diễn các facets là dọc hay ngang dựa trên lựa chọn “v” hoặc “h”.

# %%
#Tạo mọt facet với các nhóm phân loại dựa trên class
ggplot(mpg) + geom_point(aes(hwy, displ)) + facet_wrap(c("class"))
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
#Muốn hiển thị label chi tiết hơn
ggplot(mpg) + geom_point(aes(hwy, displ)) + facet_wrap(c("class"), labeller = "label_both")
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
#Thay đổi vị trí của các label xuống dưới
ggplot(mpg) + geom_point(aes(hwy, displ)) + facet_wrap(c("class"), labeller = "label_both", strip.position = "bottom")
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
#Thay đổi chiều hiển thị facets từ ngang sang dọc
ggplot(mpg) + geom_point(aes(hwy, displ)) + facet_wrap(c("class"), dir = "v", strip.position = "bottom")
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
#Các facet đang có scale fixed, chúng ta muốn cho trục y free tức là mỗi một facet sẽ có một scale riêng
ggplot(mpg) + geom_point(aes(hwy, displ)) + facet_wrap(c("class"), dir = "v", strip.position = "bottom", scales = "free_y")
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
#Nếu muốn các đồ thị lặp lại dữ liệu và chỉ hightlight các category thuộc facet đó thì phải tạo một facet 
# không chứa facet variable
ggplot(mpg,aes(displ, hwy)) + geom_point(data = transform(mpg, class = NULL), colour = "grey") + geom_point() + 
facet_wrap(c("class"), dir = "v", strip.position = "bottom", scales = "free_y")
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
#Muốn scale theo màu sắc của trục y
ggplot(mpg,aes(displ, hwy)) + geom_point(data = transform(mpg, class = NULL), colour = "grey") + geom_point() + 
facet_wrap(c("class"), strip.position = "bottom")
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
#Bản chất đồ thị trên gồm 2 lớp, lớp đầu tiên là tô cho toàn bộ đồ thị màu grey, 
#bước thứ 2 là ở geom_point() bên dưới, chỉ những điểm có category thuộc facet mới được tô màu đè lên lớp 1. 
#Tô màu theo scale thật sặc sỡ
ggplot(mpg,aes(displ, hwy)) + geom_point(aes(colour = hwy)) + facet_wrap(c("class"), strip.position = "bottom") + 
scale_color_gradientn(colours = terrain.colors(10,alpha = 0.4))
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
#Điều chỉnh thêm theme cho màu sắc
ggplot(mpg,aes(displ, hwy)) + geom_point(aes(colour = hwy)) + theme_dark() + facet_wrap(c("class"), strip.position = "bottom") +
scale_color_gradientn(colours = terrain.colors(10,alpha = 0.4))
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %% [markdown]
# Thiết lập giới hạn cho scale
#
#  lims(): thiết lập giới hạn cho các category
#
#  xlim(): Thiết lập giới hạn cho trục x
#
#  ylim(): Thiết lập giới hạn cho trục y

# %%
#Đồ thị gốc 
ggplot(mpg) + geom_point(aes(hwy, displ))
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
#Thiết lập giới hạn cho x từ 15-20
ggplot(mpg) + geom_point(aes(hwy, displ)) + xlim(15,20)
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windowsWarning message:
# "Removed 152 rows containing missing values (geom_point)."
# plot without title

# %%
#Thiết lập giới hạn cho y từ 12-20
ggplot(mpg) + geom_point(aes(hwy, displ)) + ylim(3,7)
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windowsWarning message:
# "Removed 100 rows containing missing values (geom_point)."
# plot without title

# %%
#Thiết lập giới hạn cho class thuộc các nhóm
c("compact","midsize","suv","minivan")
ggplot(mpg) + geom_point(aes(hwy, displ, colour = class)) + lims(colour = c("compact","midsize","suv","minivan"))
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# [1] "compact" "midsize" "suv"     "minivan"
# plot without title

# %%
# Sử dụng dataset pressure
df <- pressure
head(df)
## temperature pressure
## 1 0 0.0002
## 2 20 0.0012
## 3 40 0.0060
## 4 60 0.0300
## 5 80 0.0900
## 6 100 0.2700
# Tạo line graph sử dụng hàm ggplot()
library(ggplot2)
ggplot(df, aes(x=temperature, y=pressure)) + geom_line()
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
#   temperature pressure
# 1   0         0.0002
# 2  20         0.0012
# 3  40         0.0060
# 4  60         0.0300
# 5  80         0.0900
# 6 100         0.2700
# plot without title

# %%
# giới hạn vùng cho trục tọa độ sử sụng xlim và ylim
ggplot(df, aes(x=temperature, y=pressure)) + geom_line() + ylim(200, max(pressure))
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windowsWarning message:
# "Removed 15 row(s) containing missing values (geom_path)."
# plot without title

# %%
ggplot(df, aes(x=temperature, y=pressure)) + geom_line() + xlim(100, 500)
# Out:
# Warning message:
# "Removed 5 row(s) containing missing values (geom_path)."
# plot without title

# %%
# Thêm points vào line graph
ggplot(df, aes(x=temperature, y=pressure)) + geom_line() + geom_point()
# Out:
# plot without title

# %%
# Với log y-axis
ggplot(df, aes(x=temperature, y=pressure)) + geom_line() + geom_point() + scale_y_log10()
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %% [markdown]
# # Ggplot2-Tạo line graph với multiple lines

# %%
# Tạo data frames
nmonths = 24
x = seq(as.Date("2015/1/1"), by = "month", length.out = nmonths)
df1 <- data.frame(dates = x,Variable = rnorm(mean = 0.75,nmonths))
df2 <- data.frame(dates = x,Variable = rnorm(mean = -0.75,nmonths))
df3 <- data.frame(dates = x,Variable = rnorm(mean = 0.3,nmonths))
head(df1) 
head(df2) 
head(df3)
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
#   dates      Variable
# 1 2015-01-01 -0.6044561
# 2 2015-02-01  0.3018975
# 3 2015-03-01  1.4748498
# 4 2015-04-01 -0.0718481
# 5 2015-05-01  0.9710530
# 6 2015-06-01  1.1181581
#   dates      Variable
# 1 2015-01-01 -0.82646096
# 2 2015-02-01  0.05739869
# 3 2015-03-01 -0.29060724
# 4 2015-04-01 -0.72854949
# 5 2015-05-01 -2.32795873
# 6 2015-06-01 -1.58827757
#   dates      Variable
# 1 2015-01-01  0.9698811
# 2 2015-02-01  1.8447058
# 3 2015-03-01 -0.6909752
# 4 2015-04-01  0.1187989
# 5 2015-05-01 -1.0770992
# 6 2015-06-01  0.3268902

# %%
# Tạo multiple lines
library(ggplot2)
p <- ggplot() + geom_line(data = df1, aes(x = dates, y = Variable),
        color = "blue") + geom_line(data = df2, aes(x = dates, y = Variable),
        color = "red") + geom_line(data = df3, aes(x = dates, y = Variable),
        color = "green")
print(p)
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
# Tạo category cho 3 data frames và gộp chúng lại sử dụng dplyr
library(dplyr)
df <- df1 %>% mutate(cat = "A") %>% bind_rows(df2 %>%
mutate(cat = "B")) %>% bind_rows(df3 %>% mutate(cat = "C"))
head(df)
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#   dates      Variable   cat
# 1 2015-01-01 -0.6044561 A
# 2 2015-02-01  0.3018975 A
# 3 2015-03-01  1.4748498 A
# 4 2015-04-01 -0.0718481 A
# 5 2015-05-01  0.9710530 A
# 6 2015-06-01  1.1181581 A

# %%
# Tạo multiple lines graphs
ggplot(df, aes(x = dates, y = Variable, color = cat)) + geom_line()
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
#Thay đổi hình dạng của lines
ggplot(df1, aes(x = dates, y = Variable)) + geom_line(linetype="dashed", size=1, colour="blue")
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
#Thay đổi hình dạng của points (shape = 0->25)
ggplot(df1, aes(x = dates, y = Variable)) + geom_line() + geom_point(size=4, shape=22, colour="darkred", fill="pink")
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %% [markdown]
# # Ggplot2-Graph with a Shaded Area

# %%
ggplot(df1, aes(x = dates, y = Variable)) + geom_line() + geom_area()
# Out:
# plot without title

# %%
ggplot(df1, aes(x = dates, y = Variable)) + geom_line() + geom_area(colour="black", fill="green", alpha=.2)
# Tạo 80% transparent với thiết lập alpha bằng 0.2
# Việc này giúp cho chúng ta vẫn thấy những đường lưới hiển thị mờ
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
# Thử với alpha = 0.8
ggplot(df1, aes(x = dates, y = Variable)) + geom_line() + geom_area(colour="black", fill="green", alpha=.8)
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %% [markdown]
# # Ggplot2-Tạo Stacked Area Graph

# %%
ggplot(df, aes(x = dates, y = Variable, fill = cat)) + geom_area()
# Out:
# plot without title

# %%
ggplot(df, aes(x = dates, y = Variable, fill = cat)) + 
            geom_area(colour="black", size=.2, alpha=.4) + 
            scale_fill_brewer(palette="Blues", breaks=rev(levels(cat)))
# Out:
# plot without title

# %% [markdown]
# # Ggplot2-Thêm Confidence Region

# %%
# Tính 95% confidence interval cho variable
# Viết hàm tính CI
confidence_interval <- function(vector, interval) {
    # Standard deviation of sample
    vec_sd <- sd(vector)
    # Sample size
    n <- length(vector)
    # Mean of sample
    vec_mean <- mean(vector)
    # Error according to t distribution
    error <- qt((interval + 1)/2, df = n - 1) * vec_sd / sqrt(n)
    # Confidence interval as a vector
    # result <- data.frame("lower" = vec_mean - error, "upper" = vec_mean + error) 
    # Tuy nhiên để tạo ra hai cột lower và upper cho vector variable làm như sau
    result <- data.frame("lower" = vector - error, "upper" = vector + error)
    return(result) 
}
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows

# %%
# Ví dụ
vector <- c(12, 17, 24, 35, 23, 34, 56)
confidence_interval(vector, 0.90)
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
#   lower     upper
# 1  1.258268 22.74173
# 2  6.258268 27.74173
# 3 13.258268 34.74173
# 4 24.258268 45.74173
# 5 12.258268 33.74173
# 6 23.258268 44.74173
# 7 45.258268 66.74173

# %%
library(magrittr)
range <- confidence_interval(df1$Variable, 0.95)
df1 <- cbind(df1, range)
head(df1)
# Out:
#   dates      Variable   lower      upper
# 1 2015-01-01 -0.6044561 -1.1194066 -0.0895055
# 2 2015-02-01  0.3018975 -0.2130531  0.8168481
# 3 2015-03-01  1.4748498  0.9598992  1.9898003
# 4 2015-04-01 -0.0718481 -0.5867987  0.4431025
# 5 2015-05-01  0.9710530  0.4561024  1.4860035
# 6 2015-06-01  1.1181581  0.6032075  1.6331086

# %%
ggplot(df1, aes(x = dates, y= Variable)) + geom_ribbon(aes(ymin = lower, ymax = upper), alpha=0.2) + geom_line()
# Out:
# plot without title

# %%
# With a dotted line for upper and lower bounds
ggplot(df1, aes(x=dates, y=Variable)) + geom_line(aes(y=lower), 
            colour="grey50", linetype="dotted") + geom_line(aes(y=upper), 
            colour="grey50", linetype="dotted") + geom_line()
# Out:
# plot without title

# %%
library(ggplot2)
# Dữ liệu demo: economics trong gói ggplot2
head(economics)
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
#   date       pce   pop    psavert uempmed unemploy
# 1 1967-07-01 506.7 198712 12.6    4.5     2944
# 2 1967-08-01 509.8 198911 12.6    4.7     2945
# 3 1967-09-01 515.6 199113 11.9    4.6     2958
# 4 1967-10-01 512.2 199311 12.9    4.9     3143
# 5 1967-11-01 517.4 199498 12.8    4.7     3066
# 6 1967-12-01 525.1 199657 11.8    4.8     3018

# %%
# Basic line plot
ggplot(data = economics, aes(x = date, y = pop))+ geom_line(color = "#00AFBB", size = 2)
# Out:
# plot without title

# %%
# Plot a subset of the data
ss <- subset(economics, date > as.Date("2006-1-1"))
ggplot(data = ss, aes(x = date, y = pop)) + geom_line(color = "#FC4E07", size = 2)
# Out:
# plot without title

# %%
#Điều chỉnh kích thước line
ggplot(data = economics, aes(x = date, y = pop)) + geom_line(aes(size = unemploy/pop), color = "#FC4E07")
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# plot without title

# %%
# Để tạo multiple plot bởi 2 biến psavert và uempmed theo dates. Đầu tiên cần định hình lại data sửu dụng tidyr package
library(tidyr)
library(dplyr)
df <- economics %>% select(date, psavert, uempmed) %>%
gather(key = "variable", value = "value", -date)
head(df, 3)
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# Attaching package: 'tidyr'
#
# The following object is masked from 'package:magrittr':
#
#     extract
#   date       variable value
# 1 1967-07-01 psavert  12.6
# 2 1967-08-01 psavert  12.6
# 3 1967-09-01 psavert  11.9

# %%
# Multiple line plot
ggplot(df, aes(x = date, y = value)) + geom_line(aes(color = variable), size = 1) + 
                                       scale_color_manual(values = c("#00AFBB", "#E7B800")) + theme_minimal()
# Out:
# plot without title

# %%
# Area plot
ggplot(df, aes(x = date, y = value)) + geom_area(aes(color = variable, fill = variable),
            alpha = 0.5, position = position_dodge(0.8)) + scale_color_manual(values = c("#00AFBB", "#E7B800")) +
            scale_fill_manual(values = c("#00AFBB", "#E7B800"))
# Out:
# plot without title

# %%
# Base plot with date axis
p <- ggplot(data = economics, aes(x = date, y = psavert)) + geom_line(color = "#00AFBB", size = 1)
p
# Out:
# plot without title

# %%
# Set axis limits c(min, max)
min <- as.Date("2002-1-1")
max <- NA
p + scale_x_date(limits = c(min, max))
# Out:
# Warning message:
# "Removed 414 row(s) containing missing values (geom_path)."
# plot without title

# %% [markdown]
# # Ggplot2-Định dạng date axis labels
#
# Key function: scale_x_date().
#
# To format date axis labels, you can use different combinations of days, weeks, months and years:
#
# Weekday name: use %a and %A for abbreviated and full weekday name, respectively
#
# Month name: use %b and %B for abbreviated and full month name, respectively
#
# %d: day of the month as decimal number
#
# %Y: Year with century.
#
# See more options in the documentation of the function ?strptime

# %%
# Format : month/year 
p + scale_x_date(date_labels = "%b/%Y")
# Out:
# plot without title

# %% [markdown]
# # Ggplot2-Add trend smoothed line

# %%
p + stat_smooth( color = "#FC4E07", fill = "#FC4E07", method = "loess" )
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [markdown]
# # ggfortify- ggpmisc
#
# - ggfortify là package mở rộng của ggplot2
#
# ggfortify vẽ biểu đồ chuỗi thời gian (plot time series objects)
# zoo::zooreg(), xts::xts(), timeSeries::timSeries(), tseries::irts(), forecast::forecast(), vars:vars().
#
# - ggpmisc package: cung cấp 2 phương pháp cho time series object:
#
# stat_peaks() finds at which x positions local y maxima are located, and stat_valleys() finds at which x positions local y minima are located.
#
# Visualize a time series object, using the data set AirPassengers (monthly airline passenger numbers 1949-1960).
#
# Identify shifts in mean and/or variance in a time series using the changepoint package.
#
# Detect jumps in a data using the strucchange package and the data set Nile (Measurements of the annual flow of the river Nile at Aswan).
#
# Detect peaks and valleys using the ggpmisc package and the data set lynx (Annual Canadian Lynx trappings 1821–1934).

# %%
# Cài đặt
install.packages( c("ggfortify", "changepoint", "strucchange", "ggpmisc") )
library(ggfortify)
library(magrittr) 
# for piping %>%
# Plot ts objects
autoplot(AirPassengers)
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windowsalso installing the dependencies 'tibble', 'dplyr'
#   There is a binary version available but the source version is later:
#        binary source needs_compilation
# tibble  3.0.0  3.0.1              TRUE
#
#   Binaries will be installed
# Warning message:
# "package 'dplyr' is in use and will not be installed"
# package 'tibble' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'tibble'"Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# ...

# %%
# Identify change points in mean and variance
AirPassengers %>%
changepoint:: cpt.meanvar() %>% # Identify change points
autoplot()
# Out:
# plot without title

# %%
# Detect jump in a data
strucchange::breakpoints(Nile ~ 1) %>% autoplot()
# Out:
# plot without title

# %%
#Detect peaks and valleys:
library(ggpmisc)
ggplot(lynx, as.numeric = FALSE) + geom_line() + stat_peaks(colour = "red") + stat_peaks(geom = "text", colour = "red", 
                                    vjust = -0.5, x.label.fmt = "%Y") + stat_valleys(colour = "blue") +
                                    stat_valleys(geom = "text", colour = "blue", angle = 45,
                                    vjust = 1.5, hjust = 1, x.label.fmt = "%Y")+ ylim(-500, 7300)
# Out:
# Warning message:
# "package 'ggpmisc' was built under R version 3.6.3"Registered S3 method overwritten by 'xts':
#   method     from
#   as.zoo.xts zoo
# plot without title
